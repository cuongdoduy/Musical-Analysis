# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
#read all file in project_7
Data_2010 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2010.csv')
Data_2011 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2011.csv')
Data_2012 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2012.csv')
Data_2013 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2013.csv')
Data_2014 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2014.csv')
Data_2015 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2015.csv')
Data_2016 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2016.csv')
Data_2017 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2017.csv')
Data_2018 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2018.csv')
Data_2019 = pd.read_csv(r'C:\Users\tuong\Documents\JungTalentsFiles\Project_7\Project_7_Data\2019.csv')

# %%
'''1. Combine all file in to one dataframe top_spotify_songs '''
# Combine all data into 1 dataframe
top_spotify_songs = pd.concat([Data_2010,Data_2011,Data_2012,Data_2013,Data_2014,
                               Data_2015,Data_2016,Data_2017,Data_2018,Data_2019], ignore_index=True, sort=False)
# And rename column Unnamed: 0' to 'Id'
top_spotify_songs.rename(columns={'Unnamed: 0': 'Id'}, inplace=True)
top_spotify_songs
# Out:
#       Id                                              title            artist  \
# 0      1                                   Hey, Soul Sister             Train
# 1      2                               Love The Way You Lie            Eminem
# 2      3                                            TiK ToK             Kesha
# 3      4                                        Bad Romance         Lady Gaga
# 4      5                               Just the Way You Are        Bruno Mars
# ..   ...                                                ...               ...
# 598  599                Find U Again (feat. Camila Cabello)       Mark Ronson
# 599  600      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 600  601  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 601  602    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 602  603                                   Kills You Slowly  The Chainsmokers
#
#            top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 0         neo mellow  2010   97    89    67  -4     8   80  217     19     4
# 1    detroit hip hop  2010   87    93    75  -5    52   64  263     24    23
# 2          dance pop  2010  120    84    76  -3    29   71  200     10    14
# 3          dance pop  2010  119    92    70  -4     8   71  295      0     4
# 4                pop  2010  109    84    64  -5     9   43  221      2     4
# ..               ...   ...  ...   ...   ...  ..   ...  ...  ...    ...   ...
# 598        dance pop  2019  104    66    61  -7    20   16  176      1     3
# 599              pop  2019   95    79    75  -6     7   61  206     21    12
# 600        dance pop  2019  136    76    53  -5     9   65  260      7    34
# 601        dance pop  2019  114    79    60  -6    42   24  217      1     7
# 602       electropop  2019  150    44    70  -9    13   23  213      6     6
#
#      pop
# 0     83
# 1     82
# 2     80
# 3     79
# 4     78
# ..   ...
# 598   75
# 599   75
# 600   70
# 601   69
# 602   67
#
# [603 rows x 15 columns]

# %%
'''1. Create a file top_spotify_songs.csv'''
# Create a file top_spotify_songs.csv
top_spotify_songs.to_csv('top_spotify_songs.csv', index = True)

# %%
'''2. Check data type are numberic'''
top_spotify_songs.dtypes
# You can see except column 'title', 'artist' and 'top genner' all the remaining columns have data type 'int64'
# Out:
# Id            int64
# title        object
# artist       object
# top genre    object
# year          int64
# bpm           int64
# nrgy          int64
# dnce          int64
# dB            int64
# live          int64
# val           int64
# dur           int64
# acous         int64
# spch          int64
# pop           int64
# dtype: object

# %%
''' 3. What is the most popular song in the dataset?'''
# Group data by song's name to count the most popular song by 'Id'
Count_Most_Popular = top_spotify_songs.groupby('title').count().sort_values(by = 'Id', ascending = False).Id
# Check the max number of group data
Max_Count = Count_Most_Popular.max()

# Display the most popular name songs in dataset
List_Most_Popular_Songs = Count_Most_Popular[Count_Most_Popular == Max_Count].index
print('The most popular song I can show below is:')
for song in List_Most_Popular_Songs: 
    print(song)
# Out:
# The most popular song I can show below is:
# I Like It
# Written in the Stars (feat. Eric Turner)
# Kissing Strangers
# Just the Way You Are
# We Are Never Ever Getting Back Together
# Hello
# Runnin' (Lose It All)
# Here
# Say Something
# Company
# Sugar
# Stitches
# All I Ask
# Marry You
# The Hills
# Love Yourself
# A Little Party Never Killed Nobody (All We Got)
# Castle Walls (feat. Christina Aguilera)
# First Time

# %%
'''4. What artist has the most songs in the dataset?'''
'''With query'''
# Group data by artist's name to count the most popular song
Count_Most_Artist = top_spotify_songs.groupby('artist').count().sort_values(by = 'Id', ascending = False)
# Check the max number of group data by'Id' column
Max_Count = Count_Most_Artist.Id.max()

# Display the most popular artist's name in dataset
List_Most_Popular_Songs = Count_Most_Artist[Count_Most_Artist.Id == Max_Count].index
print('''The most popular artist's name I can show below is''')
for song in List_Most_Popular_Songs: 
    print(song)
# Out:
# The most popular artist's name I can show below is
# Katy Perry

# %%
'''4.What artist has the most songs in the dataset?'''
'''With bar chart'''
ShortCount_Most_Artist = Count_Most_Artist[['Id']].head(10)
ShortCount_Most_Artist = ShortCount_Most_Artist.reset_index()
plt.figure(figsize=(8, 8))
 
# Defining the values for x-axis, y-axis
# and from which dataframe the values are to be picked
plots = sb.barplot(x='artist', y='Id', data=ShortCount_Most_Artist)
 
# Iterating over the bars one-by-one
for bar in plots.patches:
   
  # Using Matplotlib's annotate function and
  # passing the coordinates where the annotation shall be done
  # x-coordinate: bar.get_x() + bar.get_width() / 2
  # y-coordinate: bar.get_height()
  # free space to be left to make graph pleasing: (0, 8)
  # ha and va stand for the horizontal and vertical alignment
  plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
    
# Setting the label for x-axis
plt.xlabel("Artist's Name", size=14)
plt.xticks(rotation=30)
 
# Setting the label for y-axis
plt.ylabel("Number of Song", size=14)
 
# Setting the title for the graph
plt.title("NUmber of song make by artist")
 
# Finally showing the plot
plt.show()

# %%
'''5. What is the most popular genre of music in the dataset?'''
'''With query'''
# Group data by top genre to count the most popular song
Count_Most_Topgenre = top_spotify_songs.groupby('top genre').count().sort_values(by = 'Id', ascending = False)
# Check the max number of group data by'Id' column
Max_Count = Count_Most_Topgenre.Id.max()

# Display the most popular artist's name in dataset
List_Most_Popular_Songs = Count_Most_Topgenre[Count_Most_Topgenre.Id == Max_Count]
print('''The most popular gener name I can show below is''', List_Most_Popular_Songs.index[0])
# Out:
# The most popular gener name I can show below is dance pop

# %%
'''5.What is the most popular genre of music in the dataset?'''
'''With bar chart'''
ShortCount_Most_Topgenre = Count_Most_Topgenre[['Id']].head(10)
ShortCount_Most_Topgenre = ShortCount_Most_Topgenre.reset_index()
plt.figure(figsize=(8, 8))

plots = sb.barplot(x='top genre', y='Id', data=ShortCount_Most_Topgenre)
 
for bar in plots.patches:
    plots.annotate(format(bar.get_height(), '.2f'),
                   (bar.get_x() + bar.get_width() / 2,
                    bar.get_height()), ha='center', va='center',
                   size=10, xytext=(0, 8),
                   textcoords='offset points')
    
plt.xlabel("Top genre", size=14)
plt.xticks(rotation=60)
plt.ylabel("Number of top gener", size=14)
plt.title("Number of song by top genre")
plt.show()

# %%
''' 6. Are there any songs in the dataset more than once?'''
# Group data by song's name to count the most popular song by 'Id'
Count_Most_Popular = top_spotify_songs.groupby('title').count().sort_values(by = 'Id', ascending = False).Id

# Display the most popular name songs in dataset
List_Most_Popular_Songs = Count_Most_Popular[Count_Most_Popular >= 2].count()
print('There are ', List_Most_Popular_Songs, 'songs in the dataset more than once')
# Out:
# There are  19 songs in the dataset more than once

# %%
'''7. Is there a relationship between popularity and danceability?'''
scatter_plot_data_7 = top_spotify_songs[['dnce', 'pop']]
scatter_plot_data_7.plot(
   x='dnce',
   y='pop',
   kind='scatter')
plt.title("The relationship between popularity and danceability")
plt.show()

# %%
'''8. Does having a higher bpm lead to having a higher energy score?'''
scatter_plot_data_8 = top_spotify_songs[['nrgy', 'bpm']]
scatter_plot_data_8.plot(
   x='nrgy', 
   y='bpm', 
   kind='scatter')
plt.title("The relationship between bpm and energy score")
plt.show()

# %%
'''9. Which genre has the highest energy score?'''
print('The',top_spotify_songs.groupby('top genre').sum().sort_values(by = 'nrgy', ascending = False).index[0],
      'genre has the highest energy score')
df = top_spotify_songs.groupby('top genre').sum()
df
# Out:
# The dance pop genre has the highest energy score
# C:\Users\tuong\AppData\Local\Temp\ipykernel_4500\2361995664.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   print('The',top_spotify_songs.groupby('top genre').sum().sort_values(by = 'nrgy', ascending = False).index[0],
# C:\Users\tuong\AppData\Local\Temp\ipykernel_4500\2361995664.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = top_spotify_songs.groupby('top genre').sum()
#                               Id    year    bpm   nrgy   dnce    dB  live  \
# top genre
# acoustic pop                 262    4024    310    122     85   -12    15
# alaska indie                 208    2013    132     34     51   -11    12
# alternative r&b              589    2019    136     40     90    -9     6
# art pop                     2655   16119    921    481    419   -64   147
# atl hip hop                  419   10054    514    411    299   -24   108
# australian dance            2266   12094    773    432    275   -27    61
# australian hip hop           231    2014     95     72     91    -4     5
# australian pop               589   10058    769    372    320   -22   112
# barbadian pop               2881   30193   1880   1027    931   -75   266
# baroque pop                  256    4024    292    138    105   -13    17
# belgian edm                  828    4032    244    134    144   -15    15
# big room                    3149   20149   1223    772    609   -49   156
# boy band                    4115   30216   1742   1204    957   -64   228
# british soul                3485   22162   1284    562    580  -119   137
# brostep                     1103    4037    242    155    121    -6    34
# canadian contemporary r&b   3384   18144   1143    583    491   -57    93
# canadian hip hop             546    4029    218    106    156   -15    17
# canadian latin               442    2016     98     47     80   -10     7
# canadian pop               11586   68520   4131   2316   2167  -207   559
# candy pop                    434    4027    218    172    139    -7    49
# celtic rock                  144    2013     85     87     42    -4    12
# chicago rap                   64    2011    125     69     63    -6    67
# colombian pop                552    6038    378    250    229   -13    58
# complextro                  2082   12092    722    471    367   -21    57
# contemporary country         537    2018     86     59     47    -6    13
# dance pop                  94622  658692  38745  23814  21573 -1707  6153
# danish pop                   373    2016    120     47     77    -6    39
# detroit hip hop              562    4028    169    137    123   -15   116
# downtempo                   1061    4035    267    114    112   -14    31
# edm                         2581   10089    502    306    318   -34    73
# electro                      311    4026    216    147    162   -17    18
# electro house                480    2017    124     88     69    -4    15
# electronic trap             1046    4036    196    152    149    -9    20
# electropop                  6045   26223   1467    848    841   -89   211
# escape room                 1163    4038    254    151    139    -6    86
# folk-pop                     658    4030    161     71     90   -20    21
# french indie pop             339    2015    123     89     76    -5    62
# hip hop                     1803    8067    375    261    296   -28    65
# hip pop                      892   12072    604    362    352   -41    83
# hollywood                    265    2014     92     82     56    -3    19
# house                        226    2014    122     73     50    -5     9
# indie pop                    184    4023    303    175     95   -10    69
# irish singer-songwriter      274    2015    129     66     57    -5    12
# latin                       2052    8070    563    322    285   -16    74
# metropopolis                 223    2014    127     72     68    -6    27
# moroccan pop                 569    2018    110     76     75    -8    20
# neo mellow                  2347   18126    982    366    475   -73   106
# permanent wave              1059    8056    549    260    171   -26    61
# pop                        19165  120903   7024   4098   4107  -336   973
# tropical house               999    6046    398    221    147   -21   104
#
#                              val    dur  acous  spch    pop
# top genre
# acoustic pop                  95    476     92     8    117
# alaska indie                   7    250     23     3     36
# alternative r&b               35    198      5    13     84
# art pop                      164   2087    278    52    502
# atl hip hop                  259   1422     50    98    250
# australian dance             323   1458    120    69    374
# australian hip hop            38    200      9     7     70
# australian pop               343   1109     33    46    327
# barbadian pop                778   3480    216   109    981
# baroque pop                  113    528      4    13    135
# belgian edm                  113    317      4     7    120
# big room                     410   2099    102    46    656
# boy band                     909   3071    162   108   1045
# british soul                 385   2808    363    48    684
# brostep                       96    395     45    14    172
# canadian contemporary r&b    307   2039    145   121    699
# canadian hip hop              68    491      5    20    147
# canadian latin                69    228     25     4     18
# canadian pop                1917   7064    678   333   2456
# candy pop                    146    326      8     9    117
# celtic rock                   63    203      7     6     80
# chicago rap                   10    379      0    20     73
# colombian pop                228    598     49    18    168
# complextro                   258   1368     84    32    404
# contemporary country          50    196      3     3     76
# dance pop                  17889  73447   3523  2910  21047
# danish pop                    34    237     29     5     80
# detroit hip hop              126    567    105    47    147
# downtempo                     66    366     31    21    123
# edm                          279   1075     55    37    391
# electro                      153    602     12    10    149
# electro house                 49    192      4     6     70
# electronic trap               78    419     25    26    159
# electropop                   571   2764    184    86   1007
# escape room                   89    332     41    17    180
# folk-pop                      38    467    130     9    113
# french indie pop              78    189      2     3     58
# hip hop                      105    970     44    36    280
# hip pop                      174   1524    156    63    333
# hollywood                     57    215      2     5     37
# house                         52    256      2    17     72
# indie pop                    147    389      0    10    139
# irish singer-songwriter       44    242     63     5     81
# latin                        259    845     51    37    249
# metropopolis                  57    214      8     4     73
# moroccan pop                  58    248      0     5     53
# neo mellow                   321   2075    530    32    540
# permanent wave                72   1065     69    13    235
# pop                         3451  13355   1060   409   4490
# tropical house                61    634      3    20    215

# %%
'''9. Which genre has the highest energy score?'''
#Group data by 'top genre' and 
Count_Number_Each_Genre = top_spotify_songs.groupby('top genre').count().Id
df = df[['Id','nrgy']]
df['Avegare of Energy Socre'] = round(df['Id'] / df['nrgy'],2)
df.sort_values(by = 'Avegare of Energy Socre', ascending = False).index[0]
# Out:
# C:\Users\tuong\AppData\Local\Temp\ipykernel_4500\10557389.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = top_spotify_songs.groupby('top genre').sum()
# 'alternative r&b'

# %%
df = top_spotify_songs.groupby('top genre').count().Id
Count_Number_Each_Genre = df.Id
df = top_spotify_songs.groupby('top genre').().Id
# Out:
# top genre
# acoustic pop                   2
# alaska indie                   1
# alternative r&b                1
# art pop                        8
# atl hip hop                    5
# australian dance               6
# australian hip hop             1
# australian pop                 5
# barbadian pop                 15
# baroque pop                    2
# belgian edm                    2
# big room                      10
# boy band                      15
# british soul                  11
# brostep                        2
# canadian contemporary r&b      9
# canadian hip hop               2
# canadian latin                 1
# canadian pop                  34
# candy pop                      2
# celtic rock                    1
# chicago rap                    1
# colombian pop                  3
# complextro                     6
# contemporary country           1
# dance pop                    327
# danish pop                     1
# detroit hip hop                2
# downtempo                      2
# edm                            5
# electro                        2
# electro house                  1
# electronic trap                2
# electropop                    13
# escape room                    2
# folk-pop                       2
# french indie pop               1
# hip hop                        4
# hip pop                        6
# hollywood                      1
# house                          1
# indie pop                      2
# irish singer-songwriter        1
# latin                          4
# metropopolis                   1
# moroccan pop                   1
# neo mellow                     9
# permanent wave                 4
# pop                           60
# tropical house                 3
# Name: Id, dtype: int64
